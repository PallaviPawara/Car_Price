# %% [markdown]
# ### Step-1: Data Pre-processing Step :

# %% [markdown]
# #### importing libraries  :

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd

# %% [markdown]
# #### importing datasets :

# %%
df = pd.read_csv(r'C:\Users\PALLAVI\Downloads\car_price.csv')

# %% [markdown]
# #### View Top 5 Rows :

# %%
df.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                 ?       gas  std          two  convertible
# 1          3                 ?       gas  std          two  convertible
# 2          1                 ?       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  ...  engine_size  \
# 0        rwd           front          88.6  alfa-romero  ...          130
# 1        rwd           front          88.6  alfa-romero  ...          130
# 2        rwd           front          94.5  alfa-romero  ...          152
# 3        fwd           front          99.8         audi  ...          109
# 4        4wd           front          99.4         audi  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# ...

# %% [markdown]
# #### View Bottom 5 Rows :

# %%
df.tail()
# Out:
#      symboling normalized_losses Fuel_type   make num_of_doors aspiration  \
# 200         -1                95       gas    std         four      sedan
# 201         -1                95       gas  turbo         four      sedan
# 202         -1                95       gas    std         four      sedan
# 203         -1                95    diesel  turbo         four      sedan
# 204         -1                95       gas  turbo         four      sedan
#
#     wheel_base engine_location  drive_wheels body_style  ...  engine_size  \
# 200        rwd           front         109.1      volvo  ...          141
# 201        rwd           front         109.1      volvo  ...          141
# 202        rwd           front         109.1      volvo  ...          173
# 203        rwd           front         109.1      volvo  ...          145
# 204        rwd           front         109.1      volvo  ...          141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# ...

# %% [markdown]
# #### Display number of Rows & Columns :

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# #### Display DataTypes :

# %%
df.dtypes
# Out:
# symboling              int64
# normalized_losses     object
# Fuel_type             object
# make                  object
# num_of_doors          object
# aspiration            object
# wheel_base            object
# engine_location       object
# drive_wheels         float64
# body_style            object
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke                object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# #### View Some Information :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %% [markdown]
# #### Replace "?" with Null Values :

# %%
df.replace("?", np.nan, inplace = True)

# %% [markdown]
# #### Check for any missing / null values in the data :

# %%
df.isna().sum().any()
# Out:
# True

# %% [markdown]
# #### Replace Null Values :

# %%
df["normalized_losses"].value_counts()
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 85      5
# 103     5
# 102     5
# 65      5
# 168     5
# 95      5
# 74      5
# 94      5
# 122     4
# 106     4
# 148     4
# 93      4
# 118     4
# 101     3
# 83      3
# 125     3
# 115     3
# 137     3
# 154     3
# 153     2
# 194     2
# 197     2
# 188     2
# 89      2
# 81      2
# 113     2
# 129     2
# 108     2
# 164     2
# 110     2
# 145     2
# 87      2
# 192     2
# 158     2
# 119     2
# 107     1
# 98      1
# 90      1
# 121     1
# 256     1
# 77      1
# 186     1
# 78      1
# 142     1
# 231     1
# Name: normalized_losses, dtype: int64

# %%
df.normalized_losses = df.normalized_losses.fillna(11)

# %%
df["num_of_doors"].value_counts()
# Out:
# four    114
# two      89
# Name: num_of_doors, dtype: int64

# %%
df.num_of_doors = df.num_of_doors.fillna("four")

# %%
df["bore"].value_counts()
# Out:
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.43     8
# 3.31     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.39     6
# 3.05     6
# 3.58     6
# 3.54     6
# 3.01     5
# 3.7      5
# 3.35     4
# 3.74     3
# 3.59     3
# 3.17     3
# 3.47     2
# 3.8      2
# 3.63     2
# 3.94     2
# 3.33     2
# 3.13     2
# 3.5      2
# 3.24     2
# 2.92     1
# 3.34     1
# 3.08     1
# 2.68     1
# 3.76     1
# 3.6      1
# 2.54     1
# 3.61     1
# 2.99     1
# Name: bore, dtype: int64

# %%
df.bore = df.bore.fillna(23)

# %%
df["stroke"].value_counts()
# Out:
# 3.4     20
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.5      6
# 3.07     6
# 3.11     6
# 3.19     6
# 3.27     6
# 3.58     6
# 3.41     6
# 3.64     5
# 3.52     5
# 3.86     4
# 3.54     4
# 3.47     4
# 3.9      3
# 2.9      3
# 2.68     2
# 3.1      2
# 2.8      2
# 3.08     2
# 4.17     2
# 2.19     2
# 3.16     1
# 3.12     1
# 2.76     1
# 2.07     1
# 3.21     1
# 2.36     1
# 2.87     1
# Name: stroke, dtype: int64

# %%
df.stroke = df.stroke.fillna(20)

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 114     6
# 62      6
# 160     6
# 101     6
# 84      5
# 76      5
# 145     5
# 82      5
# 97      5
# 102     5
# 86      4
# 92      4
# 123     4
# 111     4
# 85      3
# 182     3
# 73      3
# 121     3
# 207     3
# 152     3
# 90      3
# 156     2
# 94      2
# 176     2
# 52      2
# 161     2
# 162     2
# 155     2
# 112     2
# 56      2
# 184     2
# 100     2
# 58      1
# 64      1
# 48      1
# 120     1
# 140     1
# 115     1
# 72      1
# 154     1
# 134     1
# 142     1
# 175     1
# 262     1
# 135     1
# 78      1
# 143     1
# 60      1
# 106     1
# 55      1
# 288     1
# 200     1
# Name: horsepower, dtype: int64

# %%
df.horsepower = df.horsepower.fillna(19)

# %%
df["peak_rpm"].value_counts()
# Out:
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5800     7
# 5250     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 4400     3
# 5900     3
# 4250     3
# 5100     3
# 6600     2
# 4900     1
# 5750     1
# 4650     1
# 5300     1
# 5600     1
# Name: peak_rpm, dtype: int64

# %%
df.peak_rpm = df.peak_rpm.fillna(37)

# %%
df["price"].value_counts()
# Out:
# 8921     2
# 13499    2
# 7775     2
# 18150    2
# 6229     2
#         ..
# 7999     1
# 7799     1
# 7603     1
# 12440    1
# 22470    1
# Name: price, Length: 186, dtype: int64

# %%
df.price = df.price.fillna(37)

# %%
df.isna().sum().any()
# Out:
# False

# %% [markdown]
# #### View Some Statistics :

# %%
df.describe()
# Out:
#         symboling  drive_wheels      length       width      height  \
# count  205.000000    205.000000  205.000000  205.000000  205.000000
# mean     0.834146     98.756585  174.049268   65.907805   53.724878
# std      1.245307      6.021776   12.337289    2.145204    2.443522
# min     -2.000000     86.600000  141.100000   60.300000   47.800000
# 25%      0.000000     94.500000  166.300000   64.100000   52.000000
# 50%      1.000000     97.000000  173.200000   65.500000   54.100000
# 75%      2.000000    102.400000  183.100000   66.900000   55.500000
# max      3.000000    120.900000  208.100000   72.300000   59.800000
#
#        curb_weight  engine_size  compression_ratio    city_mpg  highway_mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          5                11       gas  std          two  convertible
# 1          5                11       gas  std          two  convertible
# 2          3                11       gas  std          two    hatchback
# 3          4               164       gas  std         four        sedan
# 4          4               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  ...  engine_size  \
# 0        rwd           front          88.6  alfa-romero  ...          130
# 1        rwd           front          88.6  alfa-romero  ...          130
# 2        rwd           front          94.5  alfa-romero  ...          152
# 3        fwd           front          99.8         audi  ...          109
# 4        4wd           front          99.4         audi  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# ...

# %%
df1 = df[["Fuel_type", "make", "num_of_doors", "aspiration", "wheel_base", "engine_location", "body_style", "engine_type", "num_of_cylinders", "fuel_system"]]

# %%
df1.head()
# Out:
#   Fuel_type make num_of_doors   aspiration wheel_base engine_location  \
# 0       gas  std          two  convertible        rwd           front
# 1       gas  std          two  convertible        rwd           front
# 2       gas  std          two    hatchback        rwd           front
# 3       gas  std         four        sedan        fwd           front
# 4       gas  std         four        sedan        4wd           front
#
#     body_style engine_type num_of_cylinders fuel_system
# 0  alfa-romero        dohc             four        mpfi
# 1  alfa-romero        dohc             four        mpfi
# 2  alfa-romero        ohcv              six        mpfi
# 3         audi         ohc             four        mpfi
# 4         audi         ohc             five        mpfi

# %% [markdown]
# ##### Transform non-numerical into numerical column :

# %%
from sklearn.preprocessing import LabelEncoder
for column in df1.columns:
        if df1[column].dtype == np.number :
            continue
        df1[column] = LabelEncoder().fit_transform(df1[column])
# Out:
# <ipython-input-124-b5279cb7835f>:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df1[column].dtype == np.number :
# <ipython-input-124-b5279cb7835f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column] = LabelEncoder().fit_transform(df1[column])

# %%
df1.head()
# Out:
#    Fuel_type  make  num_of_doors  aspiration  wheel_base  engine_location  \
# 0          1     0             1           0           2                0
# 1          1     0             1           0           2                0
# 2          1     0             1           2           2                0
# 3          1     0             0           3           1                0
# 4          1     0             0           3           0                0
#
#    body_style  engine_type  num_of_cylinders  fuel_system
# 0           0            0                 2            5
# 1           0            0                 2            5
# 2           0            5                 3            5
# 3           1            3                 2            5
# 4           1            3                 1            5

# %% [markdown]
# #### Drop ""Fuel_type", "make", "num_of_doors", "aspiration", "wheel_base", "engine_location", "body_style", "engine_type", "num_of_cylinders", "fuel_system"" Column :

# %%
df = df.drop(["Fuel_type", "make", "num_of_doors", "aspiration", "wheel_base", "engine_location", "body_style", "engine_type", "num_of_cylinders", "fuel_system"]  , axis =1 )

# %%
df.head()
# Out:
#    symboling normalized_losses  drive_wheels  length  width  height  \
# 0          5                11          88.6   168.8   64.1    48.8
# 1          5                11          88.6   168.8   64.1    48.8
# 2          3                11          94.5   171.2   65.5    52.4
# 3          4               164          99.8   176.6   66.2    54.3
# 4          4               164          99.4   176.6   66.4    54.3
#
#    curb_weight  engine_size  bore stroke  compression_ratio horsepower  \
# 0         2548          130  3.47   2.68                9.0        111
# 1         2548          130  3.47   2.68                9.0        111
# 2         2823          152  2.68   3.47                9.0        154
# 3         2337          109  3.19    3.4               10.0        102
# 4         2824          136  3.19    3.4                8.0        115
#
#   peak_rpm  city_mpg  highway_mpg  price
# 0     5000        21           27  13495
# 1     5000        21           27  16500
# ...

# %% [markdown]
# #### Combine both the Datasets :

# %%
df_combined = pd.concat([ df1 , df] ,axis=1)

# %%
df_combined.head()
# Out:
#    Fuel_type  make  num_of_doors  aspiration  wheel_base  engine_location  \
# 0          1     0             1           0           2                0
# 1          1     0             1           0           2                0
# 2          1     0             1           2           2                0
# 3          1     0             0           3           1                0
# 4          1     0             0           3           0                0
#
#    body_style  engine_type  num_of_cylinders  fuel_system  ...  curb_weight  \
# 0           0            0                 2            5  ...         2548
# 1           0            0                 2            5  ...         2548
# 2           0            5                 3            5  ...         2823
# 3           1            3                 2            5  ...         2337
# 4           1            3                 1            5  ...         2824
#
# ...

# %% [markdown]
# #### View Correlation :

# %%
df_combined.corr()
# Out:
#                    Fuel_type      make  num_of_doors  aspiration  wheel_base  \
# Fuel_type           1.000000 -0.401397      0.188496   -0.147853   -0.132257
# make               -0.401397  1.000000     -0.052803    0.063028    0.066465
# num_of_doors        0.188496 -0.052803      1.000000   -0.685640    0.104877
# aspiration         -0.147853  0.063028     -0.685640    1.000000   -0.155745
# wheel_base         -0.132257  0.066465      0.104877   -0.155745    1.000000
# engine_location     0.040070 -0.057191      0.139129   -0.277009    0.147865
# body_style         -0.113191  0.054265     -0.151516    0.089494   -0.004317
# engine_type         0.082695 -0.102963      0.062647   -0.037024   -0.116823
# num_of_cylinders    0.110617 -0.133119      0.155968   -0.048408    0.223238
# fuel_system         0.041529  0.288086      0.006980   -0.065079    0.424686
# symboling           0.194311 -0.059866      0.663595   -0.596135   -0.041671
# ...

# %% [markdown]
# #### Visualise Correlation Using Heatmap :

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df_combined.corr() , annot = True , fmt = '.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Extracting dependent and independent Variables :

# %%
df.shape
# Out:
# (205, 16)

# %%
x= df_combined.iloc[:, :-1]
y= df_combined.iloc[:, 25]

# %%
x.head()
# Out:
#    Fuel_type  make  num_of_doors  aspiration  wheel_base  engine_location  \
# 0          1     0             1           0           2                0
# 1          1     0             1           0           2                0
# 2          1     0             1           2           2                0
# 3          1     0             0           3           1                0
# 4          1     0             0           3           0                0
#
#    body_style  engine_type  num_of_cylinders  fuel_system  ...  height  \
# 0           0            0                 2            5  ...    48.8
# 1           0            0                 2            5  ...    48.8
# 2           0            5                 3            5  ...    52.4
# 3           1            3                 2            5  ...    54.3
# 4           1            3                 1            5  ...    54.3
#
#   curb_weight  engine_size  bore  stroke  compression_ratio  horsepower  \
# ...

# %%
y.head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: object

# %% [markdown]
# #### Splitting the dataset into training and test set :

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state=0)

# %% [markdown]
# ### Step: 2- Fitting our Milti Linear Regression model to the Training set :

# %%
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Step: 3- Prediction of Test set results :

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([ 5718.56714536, 16157.70167535, 13430.86950019,   706.39139997,
#        11661.80101859, 15025.78823112,  6406.96066785,  4414.41915857,
#        20525.16673252,  7206.11267652, 16168.25657906, 28928.56237398,
#        12924.39952147, 14008.81534325,  7377.65915935, 14206.25759475,
#         6438.74319973, 18756.62785397,  8521.74054742,  6438.70988712,
#         8484.59803315, 17642.08197054,  4754.82241153, 14523.2379346 ,
#        18943.02716134,  6911.62780192,  5813.22131985, 16086.48482223,
#         6471.50624901,  5524.04559231,  7853.86039748,  9040.12066758,
#        19464.03122009,  9458.03988447,  7863.92613145, 22226.87423691,
#         9458.4800864 , 14502.09963131,  5682.11891856, 39569.29004229,
#         5503.49518409])

# %% [markdown]
# #### Check the score for training dataset and test dataset :

# %%
print('Train Score: ', regressor.score(x_train, y_train))
# Out:
# Train Score:  0.8942877949405964

# %%
print('Test Score: ', regressor.score(x_test, y_test))
# Out:
# Test Score:  0.5247501439812086

# %%
print(regressor.intercept_)
# Out:
# -89540.90177136454

# %%
coeff_df = pd.DataFrame(regressor.coef_,x_test.columns,columns=["coefficient"])

# %%
coeff_df
# Out:
#                     coefficient
# Fuel_type          16608.357092
# make                1871.260680
# num_of_doors       -2269.360322
# aspiration          -570.613560
# wheel_base          1919.219135
# engine_location    12875.138374
# body_style          -148.115919
# engine_type          -99.113124
# num_of_cylinders    -844.689715
# fuel_system          179.539474
# symboling            463.259609
# normalized_losses      4.128058
# drive_wheels          32.114162
# length               -80.038821
# width                651.916068
# height               360.056548
# curb_weight            1.944665
# engine_size          113.561006
# bore                1452.662420
# stroke             -1168.854562
# compression_ratio   1211.447381
# horsepower            -4.117699
# peak_rpm               0.929911
# city_mpg             125.222730
# highway_mpg         -110.132296

# %% [markdown]
# #### ...................................................... Thank You ..........................................................
